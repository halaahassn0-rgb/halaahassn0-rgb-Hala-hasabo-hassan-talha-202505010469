# %% [markdown]
# Pseudocode while yes:
# input (the first quiz)
# input (the secound quiz)
# input(the third quiz)
# average = (quiz1+quiz2+quiz3)/3
# if average >=50: print ("Pass")
# else:
# print ("Fail")
# Algorithm Structure
# Sequence: the order for thr input
# Selection: if statement
# Iteration: while loop

# %% [markdown]
# What are the input:
# -Quiz 1
# -Quiz 2
# - Quiz 3
# What is the process?
# First we take the 3 input from the user then calculate the average mark finally decided the mark
# What is the output? pass or fail
